# %%
                            #FIRST METHOD

#printing a welcome message 
print("Welcome to KBC\nSelect the correct altenative and get rewarded\n")
print("1. Who is king of the jungle?")

correct_answers = 0


#printing the first question
print(["Tiger","Peacock","Lion","Deer"])
a = input("write your answer")
if a.title() == "Lion":
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!!")
    correct_answers += 0
    
print("\n")

#printing the second question
print("2. Who designed the National Flag of India?")
print(["Rabindranath Tagore","Subhas Chandra Bose","Surya Sen","Pingali Venkayya"])
b = input("write your answer")
if b.title() == "Pingali Venkayya":
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!!")
    correct_answers += 0

print("\n")

#printing the third question
print("3. Name the National flower of India?")
print(["Lotus", "Hibiscus", "Rose", "Tulip"])
c = input("write your answer")
if c.title() == "Lotus":
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!!")
    correct_answers += 0

print("\n")

#printing the fourth question
print("4. Name the National fruit of India?")
print(["Guava","Mango","Papaya","Pineapple"])
d=input("write your answer")
if d.title() =="Mango":
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!!")
    correct_answers += 0

print("\n")

#calculating the total amount
# print("Number of correct answers =",correct_answers)
if correct_answers == 4:
    print("Since your all answers are right,we're giving you a bonus of Rs.1000")
    print("Congrats you've earned a total of Rs.",(correct_answers * 10000) + 1000)
elif 0 < correct_answers <= 3 :
    print("Congrats you've earned a total of Rs.",correct_answers * 10000)
else:
    print("All of your answers are wrong")





                            #SECOND METHOD
#printing a welcome message
print("Welcome to KBC\nChoose the correct alternative and get rewarded\n")

correct_answers = 0

print("\n")
#printing the first question
print("1. Who is king of the jungle?")
print("1. Tiger \t 2. Peacock \n3. Lion \t 4. Deer")
l1 = int(input("choose the correct alternative:"))

if l1 == 3:
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!! \n")
    correct_answers += 0

print("\n")
#printing the second question
print("2. Who designed the National Flag of India?")
print("1. Rabindranath Tagore \t  2. Surya Sen \n3. Subhas Chandra Bose \t  4. Pingali Venkayya")
l2 = int(input("choose the correct alternative:"))
if l2 == 4:
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!! \n")
    correct_answers += 0

print("\n")
#printing the third question
print("3. Name the National flower of India?")
print("1. Lotus \t 2. Hibiscus \n3. Rose \t 4. Tulip")
l3 = int(input("choose the correct alternative:"))
if l3 == 1:
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!! \n")
    correct_answers += 0

print("\n")
#printing the fourth question
print("4. Name the National fruit of India?")
print("1. Guava \t 2. Mango \n3. Papaya \t 4. Pineapple")
l4 = int(input("choose the correct alternative:"))
if l4 == 2:
    print("correct answer")
    correct_answers += 1
else:
    print("wrong answer!! \n")
    correct_answers += 0

print("\n")
# print("Your total balance is =",correct_answers)
if correct_answers == 4:
    print("Since your all answers are right,we're giving you a bonus of Rs.1000")
    print("Congrats you've earned a total of Rs.",(correct_answers * 10000) + 1000)
elif 0 < correct_answers <= 3 :
    print("Congrats you've earned a total of Rs.",correct_answers * 10000)
else:
    print("All of your answers are wrong")
